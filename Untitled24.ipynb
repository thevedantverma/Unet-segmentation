# %%
# !pip install patchify
import cv2
from PIL import Image
import matplotlib.pyplot as plt
# Out:
# Requirement already satisfied: patchify in /usr/local/lib/python3.10/dist-packages (0.2.3)
# Requirement already satisfied: numpy<2,>=1 in /usr/local/lib/python3.10/dist-packages (from patchify) (1.25.2)

# %%
import numpy as np
import pandas as pd
from patchify import  patchify
import torch
from sklearn import preprocessing
from sklearn.preprocessing import MinMaxScaler, StandardScaler

# %%
import os
for dirname, _, filenames in os.walk('/content/drive/MyDrive/Semantic segmentation dataset'):
  for filename in filenames:
        print(os.path.join(dirname, filename))
# Out:
# /content/drive/MyDrive/Semantic segmentation dataset/classes.json
# /content/drive/MyDrive/Semantic segmentation dataset/Tile 1/masks/image_part_001.png
# /content/drive/MyDrive/Semantic segmentation dataset/Tile 1/masks/image_part_008.png
# /content/drive/MyDrive/Semantic segmentation dataset/Tile 1/masks/image_part_003.png
# /content/drive/MyDrive/Semantic segmentation dataset/Tile 1/masks/image_part_006.png
# /content/drive/MyDrive/Semantic segmentation dataset/Tile 1/masks/image_part_005.png
# /content/drive/MyDrive/Semantic segmentation dataset/Tile 1/masks/image_part_007.png
# /content/drive/MyDrive/Semantic segmentation dataset/Tile 1/masks/image_part_002.png
# /content/drive/MyDrive/Semantic segmentation dataset/Tile 1/masks/image_part_009.png
# /content/drive/MyDrive/Semantic segmentation dataset/Tile 1/masks/image_part_004.png
# /content/drive/MyDrive/Semantic segmentation dataset/Tile 1/images/image_part_002.jpg
# /content/drive/MyDrive/Semantic segmentation dataset/Tile 1/images/image_part_009.jpg
# /content/drive/MyDrive/Semantic segmentation dataset/Tile 1/images/image_part_008.jpg
# /content/drive/MyDrive/Semantic segmentation dataset/Tile 1/images/image_part_003.jpg
# /content/drive/MyDrive/Semantic segmentation dataset/Tile 1/images/image_part_005.jpg
# /content/drive/MyDrive/Semantic segmentation dataset/Tile 1/images/image_part_006.jpg
# /content/drive/MyDrive/Semantic segmentation dataset/Tile 1/images/image_part_004.jpg
# /content/drive/MyDrive/Semantic segmentation dataset/Tile 1/images/image_part_001.jpg
# /content/drive/MyDrive/Semantic segmentation dataset/Tile 1/images/image_part_007.jpg
# /content/drive/MyDrive/Semantic segmentation dataset/Tile 2/masks/image_part_003.png
# /content/drive/MyDrive/Semantic segmentation dataset/Tile 2/masks/image_part_006.png
# /content/drive/MyDrive/Semantic segmentation dataset/Tile 2/masks/image_part_002.png
# /content/drive/MyDrive/Semantic segmentation dataset/Tile 2/masks/image_part_008.png
# /content/drive/MyDrive/Semantic segmentation dataset/Tile 2/masks/image_part_004.png
# /content/drive/MyDrive/Semantic segmentation dataset/Tile 2/masks/image_part_005.png
# /content/drive/MyDrive/Semantic segmentation dataset/Tile 2/masks/image_part_001.png
# /content/drive/MyDrive/Semantic segmentation dataset/Tile 2/masks/image_part_009.png
# /content/drive/MyDrive/Semantic segmentation dataset/Tile 2/masks/image_part_007.png
# /content/drive/MyDrive/Semantic segmentation dataset/Tile 2/images/image_part_008.jpg
# /content/drive/MyDrive/Semantic segmentation dataset/Tile 2/images/image_part_006.jpg
# /content/drive/MyDrive/Semantic segmentation dataset/Tile 2/images/image_part_003.jpg
# /content/drive/MyDrive/Semantic segmentation dataset/Tile 2/images/image_part_007.jpg
# /content/drive/MyDrive/Semantic segmentation dataset/Tile 2/images/image_part_002.jpg
# /content/drive/MyDrive/Semantic segmentation dataset/Tile 2/images/image_part_004.jpg
# /content/drive/MyDrive/Semantic segmentation dataset/Tile 2/images/image_part_001.jpg
# /content/drive/MyDrive/Semantic segmentation dataset/Tile 2/images/image_part_005.jpg
# /content/drive/MyDrive/Semantic segmentation dataset/Tile 2/images/image_part_009.jpg
# /content/drive/MyDrive/Semantic segmentation dataset/Tile 4/images/image_part_001.jpg
# /content/drive/MyDrive/Semantic segmentation dataset/Tile 4/images/image_part_002.jpg
# /content/drive/MyDrive/Semantic segmentation dataset/Tile 4/images/image_part_009.jpg
# /content/drive/MyDrive/Semantic segmentation dataset/Tile 4/images/image_part_006.jpg
# /content/drive/MyDrive/Semantic segmentation dataset/Tile 4/images/image_part_008.jpg
# /content/drive/MyDrive/Semantic segmentation dataset/Tile 4/images/image_part_007.jpg
# /content/drive/MyDrive/Semantic segmentation dataset/Tile 4/images/image_part_004.jpg
# /content/drive/MyDrive/Semantic segmentation dataset/Tile 4/images/image_part_003.jpg
# /content/drive/MyDrive/Semantic segmentation dataset/Tile 4/images/image_part_005.jpg
# /content/drive/MyDrive/Semantic segmentation dataset/Tile 4/masks/image_part_001.png
# /content/drive/MyDrive/Semantic segmentation dataset/Tile 4/masks/image_part_004.png
# /content/drive/MyDrive/Semantic segmentation dataset/Tile 4/masks/image_part_003.png
# /content/drive/MyDrive/Semantic segmentation dataset/Tile 4/masks/image_part_009.png
# /content/drive/MyDrive/Semantic segmentation dataset/Tile 4/masks/image_part_005.png
# /content/drive/MyDrive/Semantic segmentation dataset/Tile 4/masks/image_part_007.png
# /content/drive/MyDrive/Semantic segmentation dataset/Tile 4/masks/image_part_006.png
# /content/drive/MyDrive/Semantic segmentation dataset/Tile 4/masks/image_part_002.png
# /content/drive/MyDrive/Semantic segmentation dataset/Tile 4/masks/image_part_008.png
# /content/drive/MyDrive/Semantic segmentation dataset/Tile 7/masks/image_part_005.png
# /content/drive/MyDrive/Semantic segmentation dataset/Tile 7/masks/image_part_006.png
# /content/drive/MyDrive/Semantic segmentation dataset/Tile 7/masks/image_part_003.png
# /content/drive/MyDrive/Semantic segmentation dataset/Tile 7/masks/image_part_007.png
# /content/drive/MyDrive/Semantic segmentation dataset/Tile 7/masks/image_part_004.png
# /content/drive/MyDrive/Semantic segmentation dataset/Tile 7/masks/image_part_002.png
# /content/drive/MyDrive/Semantic segmentation dataset/Tile 7/masks/image_part_009.png
# /content/drive/MyDrive/Semantic segmentation dataset/Tile 7/masks/image_part_001.png
# /content/drive/MyDrive/Semantic segmentation dataset/Tile 7/masks/image_part_008.png
# /content/drive/MyDrive/Semantic segmentation dataset/Tile 7/images/image_part_008.jpg
# /content/drive/MyDrive/Semantic segmentation dataset/Tile 7/images/image_part_002.jpg
# /content/drive/MyDrive/Semantic segmentation dataset/Tile 7/images/image_part_006.jpg
# /content/drive/MyDrive/Semantic segmentation dataset/Tile 7/images/image_part_005.jpg
# /content/drive/MyDrive/Semantic segmentation dataset/Tile 7/images/image_part_004.jpg
# /content/drive/MyDrive/Semantic segmentation dataset/Tile 7/images/image_part_007.jpg
# /content/drive/MyDrive/Semantic segmentation dataset/Tile 7/images/image_part_003.jpg
# /content/drive/MyDrive/Semantic segmentation dataset/Tile 7/images/image_part_001.jpg
# /content/drive/MyDrive/Semantic segmentation dataset/Tile 7/images/image_part_009.jpg
# /content/drive/MyDrive/Semantic segmentation dataset/Tile 6/masks/image_part_002.png
# /content/drive/MyDrive/Semantic segmentation dataset/Tile 6/masks/image_part_003.png
# /content/drive/MyDrive/Semantic segmentation dataset/Tile 6/masks/image_part_001.png
# /content/drive/MyDrive/Semantic segmentation dataset/Tile 6/masks/image_part_004.png
# /content/drive/MyDrive/Semantic segmentation dataset/Tile 6/masks/image_part_006.png
# /content/drive/MyDrive/Semantic segmentation dataset/Tile 6/masks/image_part_009.png
# /content/drive/MyDrive/Semantic segmentation dataset/Tile 6/masks/image_part_007.png
# /content/drive/MyDrive/Semantic segmentation dataset/Tile 6/masks/image_part_008.png
# /content/drive/MyDrive/Semantic segmentation dataset/Tile 6/masks/image_part_005.png
# /content/drive/MyDrive/Semantic segmentation dataset/Tile 6/images/image_part_004.jpg
# /content/drive/MyDrive/Semantic segmentation dataset/Tile 6/images/image_part_002.jpg
# /content/drive/MyDrive/Semantic segmentation dataset/Tile 6/images/image_part_008.jpg
# /content/drive/MyDrive/Semantic segmentation dataset/Tile 6/images/image_part_001.jpg
# /content/drive/MyDrive/Semantic segmentation dataset/Tile 6/images/image_part_009.jpg
# /content/drive/MyDrive/Semantic segmentation dataset/Tile 6/images/image_part_005.jpg
# /content/drive/MyDrive/Semantic segmentation dataset/Tile 6/images/image_part_007.jpg
# /content/drive/MyDrive/Semantic segmentation dataset/Tile 6/images/image_part_003.jpg
# /content/drive/MyDrive/Semantic segmentation dataset/Tile 6/images/image_part_006.jpg
# /content/drive/MyDrive/Semantic segmentation dataset/Tile 8/images/image_part_002.jpg
# /content/drive/MyDrive/Semantic segmentation dataset/Tile 8/images/image_part_004.jpg
# /content/drive/MyDrive/Semantic segmentation dataset/Tile 8/images/image_part_005.jpg
# /content/drive/MyDrive/Semantic segmentation dataset/Tile 8/images/image_part_003.jpg
# /content/drive/MyDrive/Semantic segmentation dataset/Tile 8/images/image_part_007.jpg
# /content/drive/MyDrive/Semantic segmentation dataset/Tile 8/images/image_part_001.jpg
# /content/drive/MyDrive/Semantic segmentation dataset/Tile 8/images/image_part_006.jpg
# /content/drive/MyDrive/Semantic segmentation dataset/Tile 8/images/image_part_008.jpg
# /content/drive/MyDrive/Semantic segmentation dataset/Tile 8/images/image_part_009.jpg
# /content/drive/MyDrive/Semantic segmentation dataset/Tile 8/masks/image_part_009.png
# /content/drive/MyDrive/Semantic segmentation dataset/Tile 8/masks/image_part_002.png
# /content/drive/MyDrive/Semantic segmentation dataset/Tile 8/masks/image_part_008.png
# /content/drive/MyDrive/Semantic segmentation dataset/Tile 8/masks/image_part_004.png
# /content/drive/MyDrive/Semantic segmentation dataset/Tile 8/masks/image_part_005.png
# /content/drive/MyDrive/Semantic segmentation dataset/Tile 8/masks/image_part_003.png
# /content/drive/MyDrive/Semantic segmentation dataset/Tile 8/masks/image_part_007.png
# /content/drive/MyDrive/Semantic segmentation dataset/Tile 8/masks/image_part_006.png
# /content/drive/MyDrive/Semantic segmentation dataset/Tile 8/masks/image_part_001.png
# /content/drive/MyDrive/Semantic segmentation dataset/Tile 5/images/image_part_007.jpg
# /content/drive/MyDrive/Semantic segmentation dataset/Tile 5/images/image_part_006.jpg
# /content/drive/MyDrive/Semantic segmentation dataset/Tile 5/images/image_part_009.jpg
# /content/drive/MyDrive/Semantic segmentation dataset/Tile 5/images/image_part_001.jpg
# /content/drive/MyDrive/Semantic segmentation dataset/Tile 5/images/image_part_005.jpg
# /content/drive/MyDrive/Semantic segmentation dataset/Tile 5/images/image_part_004.jpg
# /content/drive/MyDrive/Semantic segmentation dataset/Tile 5/images/image_part_002.jpg
# /content/drive/MyDrive/Semantic segmentation dataset/Tile 5/images/image_part_008.jpg
# /content/drive/MyDrive/Semantic segmentation dataset/Tile 5/images/image_part_003.jpg
# /content/drive/MyDrive/Semantic segmentation dataset/Tile 5/masks/image_part_001.png
# /content/drive/MyDrive/Semantic segmentation dataset/Tile 5/masks/image_part_007.png
# /content/drive/MyDrive/Semantic segmentation dataset/Tile 5/masks/image_part_002.png
# /content/drive/MyDrive/Semantic segmentation dataset/Tile 5/masks/image_part_008.png
# /content/drive/MyDrive/Semantic segmentation dataset/Tile 5/masks/image_part_006.png
# /content/drive/MyDrive/Semantic segmentation dataset/Tile 5/masks/image_part_009.png
# /content/drive/MyDrive/Semantic segmentation dataset/Tile 5/masks/image_part_004.png
# /content/drive/MyDrive/Semantic segmentation dataset/Tile 5/masks/image_part_005.png
# /content/drive/MyDrive/Semantic segmentation dataset/Tile 5/masks/image_part_003.png
# /content/drive/MyDrive/Semantic segmentation dataset/Tile 3/masks/image_part_007.png
# /content/drive/MyDrive/Semantic segmentation dataset/Tile 3/masks/image_part_008.png
# /content/drive/MyDrive/Semantic segmentation dataset/Tile 3/masks/image_part_003.png
# /content/drive/MyDrive/Semantic segmentation dataset/Tile 3/masks/image_part_006.png
# /content/drive/MyDrive/Semantic segmentation dataset/Tile 3/masks/image_part_009.png
# /content/drive/MyDrive/Semantic segmentation dataset/Tile 3/masks/image_part_004.png
# /content/drive/MyDrive/Semantic segmentation dataset/Tile 3/masks/image_part_005.png
# /content/drive/MyDrive/Semantic segmentation dataset/Tile 3/masks/image_part_002.png
# /content/drive/MyDrive/Semantic segmentation dataset/Tile 3/masks/image_part_001.png
# /content/drive/MyDrive/Semantic segmentation dataset/Tile 3/images/image_part_003.jpg
# /content/drive/MyDrive/Semantic segmentation dataset/Tile 3/images/image_part_008.jpg
# /content/drive/MyDrive/Semantic segmentation dataset/Tile 3/images/image_part_005.jpg
# /content/drive/MyDrive/Semantic segmentation dataset/Tile 3/images/image_part_004.jpg
# /content/drive/MyDrive/Semantic segmentation dataset/Tile 3/images/image_part_006.jpg
# /content/drive/MyDrive/Semantic segmentation dataset/Tile 3/images/image_part_002.jpg
# /content/drive/MyDrive/Semantic segmentation dataset/Tile 3/images/image_part_007.jpg
# /content/drive/MyDrive/Semantic segmentation dataset/Tile 3/images/image_part_001.jpg
# /content/drive/MyDrive/Semantic segmentation dataset/Tile 3/images/image_part_009.jpg

# %%
def create_dir(dir_name):
    if not os.path.exists(dir_name):
        os.makedirs(dir_name, exist_ok=True)

# %%
image_dataset=[]
for path,subdirs,files in os.walk(root_dir):
    dirname = path.split(os.path.sep)[-1]
    if dirname =="images":
        images = os.listdir(path)
        for i,image_name in enumerate(images):
            if image_name.endswith(".jpg"):
                image = cv2.imread(path+'/'+image_name,cv2.IMREAD_COLOR)
                SIZE_X = (image.shape[1]//patch_size)*patch_size
                SIZE_Y = (image.shape[0]//patch_size)*patch_size
                image = Image.fromarray(image)
                image = image.crop((0,0,SIZE_X,SIZE_Y))

                image = np.array(image)

                patches_img = patchify(image,(patch_size,patch_size,3),step=patch_size)
                for i in range(patches_img.shape[0]):
                    for j in range(patches_img.shape[1]):
                        single_patch_img = patches_img[i,j,:,:]
                        # img need flatten
                        single_patch_img = scaler.fit_transform(single_patch_img.reshape(-1, single_patch_img.shape[-1])).reshape(single_patch_img.shape)
                        single_patch_img = single_patch_img[0] #Drop the extra unecessary dimension that patchify adds.
                        image_dataset.append(single_patch_img)

# %%
mask_dataset =[]
for path,subdirs,files in os.walk(root_dir):
    dirname = path.split(os.path.sep)[-1]
    if dirname == "masks":
        masks = os.listdir(path)
        for i,mask_name in enumerate(masks):
            if mask_name.endswith(".png"):
                mask = cv2.imread(path+'/'+mask_name,1)
                mask = cv2.cvtColor(mask, cv2.COLOR_BGR2RGB)
                SIZE_X = (mask.shape[1]//patch_size)*patch_size
                SIZE_Y = (mask.shape[0]//patch_size)*patch_size
                mask = Image.fromarray(mask)
                mask = mask.crop((0,0,SIZE_X,SIZE_Y))
                mask = np.array(mask)

                patches_mask = patchify(mask,(patch_size,patch_size,3),step = patch_size)

                for i in range(patches_mask.shape[0]):
                    for j in range(patches_mask.shape[1]):
                        single_patch_mask = patches_mask[i,j,:,:]
                        single_patch_mask = single_patch_mask[0]
                        mask_dataset.append(single_patch_mask)

# %%
scaler=MinMaxScaler()
root_dir='/content/drive/MyDrive/Semantic segmentation dataset'

# %%
patch_size=256

# %%
import random
import numpy as np
image_number = random.randint(0,len(image_dataset))
plt.figure(figsize=(12,6))
plt.subplot(121)
plt.imshow(np.reshape(image_dataset[image_number], (patch_size, patch_size, 3)))
plt.subplot(122)
plt.imshow(np.reshape(mask_dataset[image_number], (patch_size, patch_size, 3)))
plt.show()
